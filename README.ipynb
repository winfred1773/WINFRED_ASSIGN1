# %% [markdown]
# ##BOOM MOVIE

# %% [markdown]
# #AUTHOR:Winfred mwangi

# %% [markdown]
# #Overview

# %% [markdown]
# This project will on the movies and authors will analyse on the domestic and foreign gross in the year 2018 which hel more than three thousand movies.Descriptive analysis of movies intake and outcome data shows that some movies require extended stays and that the number of movies was more viewed. The boom movie can use this analysis to adjust extension, avilability, and to improve on mode.

# %% [markdown]
# #Businness problem

# %% [markdown]
# The Boom movie may be able to improve their movie availability and ensure that the shop has more than enough movies available for their clients.Doing so will allow the boom movie centre to better serve its clients while also upgrading their resources to expand the scope of movie they can offer

# %% [markdown]
# #Data

# %% [markdown]
# The Boom movie centre has the many clients in the said year. Every movie is associated with either domestic or foreign gross. The data files provide the title,the studio and the year.

# %% [markdown]
# #Methods

# %% [markdown]
# This project uses descriptive analysis. This provides a useful overview of the boom movie typical domestic and foreign gross to identify movie needs.

# %% [markdown]
# #Results

# %% [markdown]
# As the years went by the movies went low.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# there is no year that the production of the movies increased maybe this could have been led by the increasing of age hence more resposility and having limited time for watching movies

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Conclusion

# %% [markdown]
# this analysis leads to the following conclusions:

# %% [markdown]
# *   In the year 2015and 2016 there was avery high number of movies produced by the studio.
# *  The IFC studio had the highest production
# *  As the years increased there was a reduction of movies recorded.

# %% [markdown]
# #Next step

# %% [markdown]
# For further and easier production in Boom Movie Mojo:
#
#
# * Increased production in movies by either bettering their technology or also hiring more staff.
#
# *   Use a better marketing technology to reach the new generations.
# *   Include all sorts of technology like youtube,instagram and telegram to reach to its clients.
#
#
# *   Having actors act the movies which relate to the recent challanges and how to cope with them
# *
#
#
#
#
#
#
# *
